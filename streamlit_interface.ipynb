# %% [markdown]
# # Interfaz Streamlit para Clasificación de Plantas
#
# Esta interfaz permite visualizar y usar el modelo de clasificación de plantas entrenado con VGG16.

# %%
# Instalación de dependencias
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: packaging<25,>=20 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.43.0)
# Requirement already satisfied: colorama in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
pip install tensorflow pillow numpy matplotlib seaborn scikit-learn
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: pillow in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (11.2.1)
# Requirement already satisfied: numpy in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (2.3.0)
# Collecting matplotlib
#   Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (4.14.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-1.17.3-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Using cached h5py-3.14.0-cp312-cp312-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.3-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Using cached markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.59.1-cp312-cp312-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from seaborn) (2.3.0)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Using cached rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Using cached optree-0.17.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cpsei\anaconda3\envs\streamlitenv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.20.0-cp312-cp312-win_amd64.whl (331.9 MB)
#    ---------------------------------------- 0.0/331.9 MB ? eta -:--:--
#    ---------------------------------------- 1.6/331.9 MB 8.4 MB/s eta 0:00:40
#    ---------------------------------------- 3.1/331.9 MB 8.8 MB/s eta 0:00:38
#     --------------------------------------- 5.0/331.9 MB 8.6 MB/s eta 0:00:38
#     --------------------------------------- 6.6/331.9 MB 8.4 MB/s eta 0:00:39
#     --------------------------------------- 7.3/331.9 MB 7.4 MB/s eta 0:00:44
#    - -------------------------------------- 8.4/331.9 MB 7.1 MB/s eta 0:00:46
#    - -------------------------------------- 8.7/331.9 MB 6.0 MB/s eta 0:00:55
#    - -------------------------------------- 10.5/331.9 MB 6.3 MB/s eta 0:00:52
#    - -------------------------------------- 12.8/331.9 MB 6.8 MB/s eta 0:00:47
#    - -------------------------------------- 14.4/331.9 MB 6.9 MB/s eta 0:00:46
#    - -------------------------------------- 16.5/331.9 MB 7.2 MB/s eta 0:00:44
#    -- ------------------------------------- 17.8/331.9 MB 7.3 MB/s eta 0:00:44
#    -- ------------------------------------- 19.7/331.9 MB 7.3 MB/s eta 0:00:43
#    -- ------------------------------------- 21.8/331.9 MB 7.4 MB/s eta 0:00:42
#    -- ------------------------------------- 23.6/331.9 MB 7.6 MB/s eta 0:00:41
#    --- ------------------------------------ 25.7/331.9 MB 7.7 MB/s eta 0:00:40
#    --- ------------------------------------ 27.8/331.9 MB 7.8 MB/s eta 0:00:40
#    --- ------------------------------------ 29.6/331.9 MB 7.8 MB/s eta 0:00:39
#    --- ------------------------------------ 31.7/331.9 MB 7.9 MB/s eta 0:00:38
#    ---- ----------------------------------- 33.3/331.9 MB 7.9 MB/s eta 0:00:38
#    ---- ----------------------------------- 34.9/331.9 MB 7.9 MB/s eta 0:00:38
#    ---- ----------------------------------- 37.0/331.9 MB 8.0 MB/s eta 0:00:37
kB)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------------- ------------------------ 2.1/5.5 MB 13.1 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.5 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 9.1 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached matplotlib-3.10.5-cp312-cp312-win_amd64.whl (8.1 MB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached scikit_learn-1.7.1-cp312-cp312-win_amd64.whl (8.7 MB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached fonttools-4.59.1-cp312-cp312-win_amd64.whl (2.3 MB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached h5py-3.14.0-cp312-cp312-win_amd64.whl (2.9 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading keras-3.11.3-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 14.7 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached markdown-3.8.2-py3-none-any.whl (106 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading scipy-1.16.1-cp312-cp312-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    - -------------------------------------- 1.3/38.5 MB 9.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/38.5 MB 11.4 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/38.5 MB 11.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.7/38.5 MB 11.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.7/38.5 MB 11.6 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.5 MB 9.6 MB/s eta 0:00:03
#    -------------- ------------------------- 14.2/38.5 MB 9.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.5/38.5 MB 9.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 16.5/38.5 MB 8.7 MB/s eta 0:00:03
#    ------------------ --------------------- 17.8/38.5 MB 8.4 MB/s eta 0:00:03
#    ------------------- -------------------- 19.1/38.5 MB 8.3 MB/s eta 0:00:03
#    --------------------- ------------------ 21.0/38.5 MB 8.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 22.8/38.5 MB 8.4 MB/s eta 0:00:02
#    ------------------------- -------------- 24.6/38.5 MB 8.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 27.0/38.5 MB 8.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.0/38.5 MB 8.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.8/38.5 MB 8.1 MB/s eta 0:00:02
#    ------------------------------- -------- 30.1/38.5 MB 8.0 MB/s eta 0:00:02
#    -------------------------------- ------- 31.2/38.5 MB 7.8 MB/s eta 0:00:01
#    --------------------------------- ------ 32.5/38.5 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.6/38.5 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.5 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.5 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 7.6 MB/s eta 0:00:00
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached wrapt-1.17.3-cp312-cp312-win_amd64.whl (38 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.17.0-cp312-cp312-win_amd64.whl (314 kB)
# Using cached rich-14.1.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, threadpoolctl, termcolor, tensorboard-data-server, scipy, pyparsing, optree, opt_einsum, ml_dtypes, mdurl, markdown, kiwisolver, joblib, h5py, google_pasta, gast, fonttools, cycler, contourpy, astunparse, absl-py, tensorboard, scikit-learn, matplotlib, markdown-it-py, seaborn, rich, keras, tensorflow
#
#    - --------------------------------------  1/33 [libclang]
#    - --------------------------------------  1/33 [libclang]
#    --- ------------------------------------  3/33 [wrapt]
#    ---- -----------------------------------  4/33 [werkzeug]
#    ------ ---------------------------------  5/33 [threadpoolctl]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    --------- ------------------------------  8/33 [scipy]
#    ---------- -----------------------------  9/33 [pyparsing]
#    ------------- -------------------------- 11/33 [opt_einsum]
#    ------------- -------------------------- 11/33 [opt_einsum]
#    ---------------- ----------------------- 14/33 [markdown]
#    ------------------- -------------------- 16/33 [joblib]
#    ------------------- -------------------- 16/33 [joblib]
#    ------------------- -------------------- 16/33 [joblib]
#    -------------------- ------------------- 17/33 [h5py]
#    -------------------- ------------------- 17/33 [h5py]
#    --------------------- ------------------ 18/33 [google_pasta]
#    ------------------------ --------------- 20/33 [fonttools]
[tensorflow]
#
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 contourpy-1.3.3 cycler-0.12.1 flatbuffers-25.2.10 fonttools-4.59.1 gast-0.6.0 google_pasta-0.2.0 h5py-3.14.0 joblib-1.5.1 keras-3.11.3 kiwisolver-1.4.9 libclang-18.1.1 markdown-3.8.2 markdown-it-py-4.0.0 matplotlib-3.10.5 mdurl-0.1.2 ml_dtypes-0.5.3 namex-0.1.0 opt_einsum-3.4.0 optree-0.17.0 pyparsing-3.2.3 rich-14.1.0 scikit-learn-1.7.1 scipy-1.16.1 seaborn-0.13.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.1.0 threadpoolctl-3.6.0 werkzeug-3.1.3 wrapt-1.17.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Crear archivo de la aplicación Streamlit
#%%writefile app_plantas.py
import streamlit as st
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
import io
from nbimporter import import_notebook

# Configuración de la página
st.set_page_config(
    page_title="Clasificador de Plantas",
    page_icon="🌱",
    layout="wide",
    initial_sidebar_state="expanded"
)

# Título principal
st.title("🌱 Clasificador de Plantas con Deep Learning")
st.markdown("---")

# Nombres de las clases (30 tipos de plantas)
class_names = [
    'Aloevera', 'Banana', 'Bilimbi', 'Cantaloupe', 'Cassava', 
    'Coconut', 'Corn', 'Cucumber', 'Curcuma', 'Eggplant',
    'French_Beans', 'Ginger', 'Guava', 'Jambu', 'Kale',
    'Longbeans', 'Mango', 'Melon', 'Orange', 'Paddy',
    'Papaya', 'Passionfruit', 'Potato', 'Raddish', 'Rose',
    'Soybeans', 'Spinach', 'Sweetpotato', 'Tobacco', 'Waterapple'
]

@st.cache_resource
def load_model():
    """Cargar el modelo entrenado desde modelo.ipynb como model_2"""
    try:
        # Importar model_2 desde modelo.ipynb usando nbimporter
        modelo_nb = import_notebook('modelo')
        model = modelo_nb.model_2
        return model
    except Exception as e:
        st.error(f"Error cargando el modelo desde modelo.ipynb: {e}")
        return None

def preprocess_image(image):
    """Preprocesar imagen para el modelo"""
    image = image.convert('RGB')
    image = image.resize((128, 128))
    img_array = np.array(image) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

def predict_plant(model, image):
    """Realizar predicción"""
    processed_img = preprocess_image(image)
    predictions = model.predict(processed_img, verbose=0)
    predicted_class = np.argmax(predictions[0])
    confidence = float(predictions[0][predicted_class])
    return predicted_class, confidence, predictions[0]

def plot_predictions(predictions, top_n=5):
    """Crear gráfico de las predicciones top N"""
    top_indices = np.argsort(predictions)[::-1][:top_n]
    top_probs = predictions[top_indices]
    top_classes = [class_names[i] for i in top_indices]
    
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.barh(range(len(top_classes)), top_probs, color='lightgreen')
    ax.set_yticks(range(len(top_classes)))
    ax.set_yticklabels(top_classes)
    ax.set_xlabel('Probabilidad')
    ax.set_title(f'Top {top_n} Predicciones')
    
    # Agregar valores en las barras
    for i, bar in enumerate(bars):
        width = bar.get_width()
        ax.text(width + 0.01, bar.get_y() + bar.get_height()/2, 
                f'{width:.3f}', ha='left', va='center')
    
    plt.tight_layout()
    return fig

# Sidebar
st.sidebar.header("⚙️ Configuración")

# Cargar modelo
with st.spinner("Cargando modelo..."):
    model = load_model()

if model is None:
    st.error("No se pudo cargar el modelo. Asegúrate de haber entrenado el modelo primero.")
    st.stop()

st.sidebar.success("✅ Modelo cargado exitosamente")

# Opciones de visualización
show_top_n = st.sidebar.slider("Mostrar top N predicciones", min_value=3, max_value=10, value=5)
confidence_threshold = st.sidebar.slider("Umbral de confianza", min_value=0.0, max_value=1.0, value=0.5, step=0.05)

# Información del modelo
st.sidebar.markdown("---")
st.sidebar.markdown("### 📊 Información del Modelo")
st.sidebar.info("""
**Arquitectura:** VGG16 + Fine-tuning

**Clases:** 30 tipos de plantas

**Precisión:** ~95.3%

**Tamaño de entrada:** 128x128 píxeles
""")

# Área principal
tab1, tab2, tab3 = st.tabs(["🔍 Clasificación", "📈 Análisis", "ℹ️ Información"])

with tab1:
    st.header("Subir imagen para clasificar")
    
    # Uploader de imagen
    uploaded_file = st.file_uploader(
        "Selecciona una imagen de una planta",
        type=['png', 'jpg', 'jpeg'],
        help="Formatos soportados: PNG, JPG, JPEG"
    )
    
    if uploaded_file is not None:
        # Mostrar imagen
        image = Image.open(uploaded_file)
        
        col1, col2 = st.columns([1, 2])
        
        with col1:
            st.image(image, caption="Imagen subida", use_column_width=True)
        
        with col2:
            # Realizar predicción
            with st.spinner("Clasificando imagen..."):
                predicted_class, confidence, all_predictions = predict_plant(model, image)
                predicted_name = class_names[predicted_class]
            
            # Mostrar resultado principal
            st.markdown("### 🎯 Resultado")
            
            if confidence >= confidence_threshold:
                st.success(f"**{predicted_name}**")
                st.metric("Confianza", f"{confidence:.2%}")
            else:
                st.warning(f"**{predicted_name}** (Baja confianza)")
                st.metric("Confianza", f"{confidence:.2%}")
        
        # Mostrar gráfico de predicciones
        st.markdown("### 📊 Distribución de Predicciones")
        fig = plot_predictions(all_predictions, show_top_n)
        st.pyplot(fig)
        
        # Tabla detallada
        with st.expander("Ver todas las predicciones"):
            results_df = {
                'Clase': class_names,
                'Probabilidad': [f"{p:.4f}" for p in all_predictions],
                'Porcentaje': [f"{p:.2%}" for p in all_predictions]
            }
            import pandas as pd
            df = pd.DataFrame(results_df)
            df = df.sort_values('Probabilidad', ascending=False).reset_index(drop=True)
            st.dataframe(df, use_container_width=True)

with tab2:
    st.header("📈 Análisis del Modelo")
    
    col1, col2 = st.columns(2)
    
    with col1:
        st.metric("Precisión del Modelo", "95.3%", "2.1%")
        st.metric("Total de Clases", "30")
        st.metric("Imágenes de Entrenamiento", "24,000")
    
    with col2:
        st.metric("Imágenes de Prueba", "6,000")
        st.metric("Arquitectura Base", "VGG16")
        st.metric("Parámetros Entrenables", "~2.1M")
    
    # Lista de clases
    st.markdown("### 🌿 Clases de Plantas Reconocidas")
    
    # Dividir en columnas para mejor presentación
    cols = st.columns(5)
    for i, plant_name in enumerate(class_names):
        with cols[i % 5]:
            st.write(f"• {plant_name}")

with tab3:
    st.header("ℹ️ Información del Proyecto")
    
    st.markdown("""
    ### 🎯 Objetivo
    Este proyecto implementa un clasificador de plantas usando transfer learning con VGG16,
    capaz de identificar 30 tipos diferentes de plantas con una precisión del 95.3%.
    
    ### 🔧 Metodología
    1. **Dataset:** 30,000 imágenes de 30 clases de plantas
    2. **Preprocesamiento:** Redimensionado a 128x128, normalización
    3. **Modelo:** VGG16 preentrenado + capas densas personalizadas
    4. **Fine-tuning:** Descongelar últimas capas para ajuste fino
    5. **Regularización:** Dropout (0.7) y Early Stopping
    
    ### 📊 Resultados
    - **Precisión en Test:** 95.27%
    - **F1-Score Promedio:** 0.95
    - **Tiempo de Entrenamiento:** ~8 horas
    
    ### 👥 Autores
    - Bruno Arezo
    - Ivan Gonzalez  
    - Camila Pazos
    """)
    
    st.markdown("---")
    st.markdown("*Desarrollado con ❤️ usando Streamlit y TensorFlow*")

# Footer
st.markdown("---")
st.markdown(
    "<div style='text-align: center; color: gray;'>🌱 Clasificador de Plantas v1.0</div>", 
    unsafe_allow_html=True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#      10 from tensorflow.keras import layers, models
#      11 import io
# ---> 12 from nbimporter import import_notebook
#      14 # Configuración de la página
#      15 st.set_page_config(
#      16     page_title="Clasificador de Plantas",
#      17     page_icon="🌱",
#      18     layout="wide",
#      19     initial_sidebar_state="expanded"
#      20 )
#
# ModuleNotFoundError: No module named 'nbimporter'

# %%
# Ejecutar la aplicación Streamlit desde el notebook
# Nota: Esto abrirá la aplicación en una nueva pestaña del navegador
import subprocess
import threading
import time
import webbrowser

def run_streamlit():
    """Ejecutar la aplicación Streamlit"""
    subprocess.run(["streamlit", "run", "app_plantas.py", "--server.port=8501"])

# Ejecutar en un hilo separado
thread = threading.Thread(target=run_streamlit)
thread.daemon = True
thread.start()

# Esperar un momento y abrir el navegador
time.sleep(3)
print("🚀 Iniciando aplicación Streamlit...")
print("📱 La aplicación se abrirá en: http://localhost:8501")
print("💡 Si no se abre automáticamente, copia y pega la URL en tu navegador")

# Abrir automáticamente el navegador
webbrowser.open('http://localhost:8501')
# Out:
# 🚀 Iniciando aplicación Streamlit...
# 📱 La aplicación se abrirá en: http://localhost:8501
# 💡 Si no se abre automáticamente, copia y pega la URL en tu navegador
# True

# %% [markdown]
# ## 🎮 Instrucciones de Uso
#
# 1. **Ejecuta todas las celdas** de este notebook en orden
# 2. **La aplicación se abrirá** automáticamente en tu navegador
# 3. **Sube una imagen** de una planta en la pestaña "Clasificación"
# 4. **Explora los resultados** y ajusta la configuración en el sidebar
# 5. **Revisa el análisis** del modelo en las otras pestañas
#
# ### 🔧 Características Principales
#
# - **Interfaz intuitiva** con pestañas organizadas
# - **Visualización de predicciones** con gráficos interactivos
# - **Configuración ajustable** de umbral de confianza
# - **Información detallada** del modelo y métricas
# - **Soporte para múltiples formatos** de imagen
#
# ### 🚀 Para Usar de Forma Independiente
#
# También puedes ejecutar la aplicación directamente desde la terminal:
#
# ```bash
# streamlit run app_plantas.py
# ```
